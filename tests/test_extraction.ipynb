# %%
import sys
from pathlib import Path

base = Path.cwd().parent
sys.path.append(str(base))

from core.extraction import extract_text_from_pdf, extract_text_pages

# Pick a sample PDF from input_docs
sample_pdf = base / "data" / "input_docs" / "im.pdf"

if not sample_pdf.exists():
    print("Please add a file named im.pdf inside data/input_docs/ before running this test.")
else:
    # Test page-wise extraction
    pages = extract_text_pages(sample_pdf, use_ocr=True)
    print("Number of pages extracted:", len(pages))
    for i, text in enumerate(pages, start=1):
        print(f"\n--- Page {i} (Preview) ---")
        print(text[:500])  # preview first 500 chars

    # Test combined extraction
    full_text = extract_text_from_pdf(sample_pdf, use_ocr=True)
    print("\n--- Full Document (Preview, 1500 chars) ---")
    print(full_text[:1500])
# Out:
# [OCR] Falling back to Tesseract on page 1
# Number of pages extracted: 1
#
# --- Page 1 (Preview) ---
# Dy Millon Rout
# -VCI Regd No- 10371
#
# Issue no, — 14
#
# Date- 03.10.24
#
# HEALTH CERTIFICATE
#
# PET .
#
# NAME: SILVER SPECIES: Feline (cat)
#
# AGE: 7 months (Approx) Owner's ir Amritansh Panigrahi
# Name:
#
# SEX: female Address: Bhubaneswar
#
# BREED: Persian Ph no: 6371719825
#
# TO WHOMEVER IT MAY CONCERN
#
# This is to certify that [ have Physically examined /months old cat, Breed -PERSIAN female
# responding by name SILVER. Dominant colour- White _. Owned by Mr Amaitansh
# Panigrali, resident of Bhubaneswar, Odisha and
# [OCR] Falling back to Tesseract on page 1
#
# --- Full Document (Preview, 1500 chars) ---
# --- Page 1 ---
# Dy Millon Rout
# -VCI Regd No- 10371
#
# Issue no, — 14
#
# Date- 03.10.24
#
# HEALTH CERTIFICATE
#
# PET .
#
# NAME: SILVER SPECIES: Feline (cat)
#
# AGE: 7 months (Approx) Owner's ir Amritansh Panigrahi
# Name:
#
# SEX: female Address: Bhubaneswar
#
# BREED: Persian Ph no: 6371719825
#
# TO WHOMEVER IT MAY CONCERN
#
# This is to certify that [ have Physically examined /months old cat, Breed -PERSIAN female
# responding by name SILVER. Dominant colour- White _. Owned by Mr Amaitansh
# Panigrali, resident of Bhubaneswar, Odisha and found her to be free from any infections or
#
# contagious diseases as per best of my knowledge.
#
# @ The Petis fully Vaccinated as per her age. The vaccination record
# is attached with this certificate. Feline tno-cat VACCINE given on
# 047.24 and due on 04.7.25, Anti Rabies stven on 19.07.24 due on
# 19.07.25.
#
# « At the time of examination, Pet is found to be in apparent healthy
# condition and 1s fit to travel by road/rail/air.
#
# B10 24
#
# ROUT
# “HDR MILLON ROUT
#
# ane 9114228L9
